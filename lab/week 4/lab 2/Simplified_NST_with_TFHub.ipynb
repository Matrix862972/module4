# %% [markdown]
# # 🎨 Neural Style Transfer - Simplified Version
# This version uses TensorFlow Hub to stylize an image using a pre-trained model.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import PIL.Image
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the style transfer model from TensorFlow Hub
hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %%
# Utility function to load image
def load_img(path_to_img):
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, (256, 256))
    img = img[tf.newaxis, :]
    return img

# %%
# Load your content and style images (change these paths as needed)
content_image = load_img(r"D:\Python\Andrew Ng Deep Learning Course\module 4\lab\week 4\lab 2\images\CarContent.jpeg")
style_image = load_img(r"D:\Python\Andrew Ng Deep Learning Course\module 4\lab\week 4\lab 2\images\sandstone.jpg")

# %%
# Stylize the image
stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
# Show the result
plt.imshow(tf.squeeze(stylized_image))
plt.axis('off')
plt.show()

# %% [markdown]
# **Note:** Make sure to upload or provide valid paths for `your_content.jpg` and `your_style.jpg`.

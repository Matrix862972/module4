# %% [markdown]
# ****Step 1: Imports****

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import numpy as np

# %% [markdown]
# **Step 2: Identity Block (No Conv Shortcut)**

# %%
def identity_block(X,f,filters,training=True):
  #Split the list of filters into 3 variables — each will be used in one Conv layer in the main path.
  F1,F2,F3=filters

  #Save a copy of the input X. This will be added back later (residual connection)
  X_shortcut=X

  #Main Path

  #Applies a 1×1 convolution to reduce or change the number of channels.
  #No padding (valid), so output shape may be smaller.
  #Number of output channels = F1.
  X = Conv2D(filters = F1,kernel_size=(1,1),padding='valid')(X)

  #Normalizes the output to speed up training and reduce internal covariate shift.
  X = BatchNormalization(axis=3)(X, training=training)

  #Applies ReLU non-linearity to add activation and remove negative values.
  X = Activation('relu')(X)

  #2nd Layer: f x f Convolution (middle layer)

  #Applies a f × f convolution (usually f=3).
  #Keeps spatial size the same (padding='same').
  #Output channels = F2.
  X = Conv2D(filters = F2,kernel_size=(f,f),strides=(1,1),padding='same')(X)

  #Normalize again followed by ReLU
  X = BatchNormalization(axis=3)(X,training=training)
  X = Activation('relu')(X)

  #3rd Layer: 1x1 Convolution (restore channels)
  X = Conv2D(filters = F3,kernel_size=(1,1),strides=(1,1),padding='valid')(X)
  X = BatchNormalization(axis=3)(X,training=training)

  #Add Shortcut
  #Adds the original input (X_shortcut) to the output of the main path
  #This is the "skip connection" or residual connection.

  X = Add()([X,X_shortcut])

  #Applies ReLU after adding the shortcut. This is the final output of the identity block.
  X = Activation('relu')(X)

  return X

# %% [markdown]
# **Step 3: Convolutional Block (With Conv Shortcut)**

# %%
def convolutional_block(X,f,filters,s=2,training=True):
  """
  X             Input tensor (e.g., a feature map)
  f             Size of the middle convolution kernel (usually 3)
  filters         List of 3 integers: number of filters for each layer
  s             Stride used in the first Conv layer and the shortcut path (typically 2 for downsampling)
  training      Whether the model is in training mode (used for BatchNorm)

  """
  #Unpack filter sizes
  #Assigns the filter sizes for each convolution layer in the main path.
  F1,F2,F3 = filters

  # Save the shortcut
  # Stores the original input so it can be added later (residual connection).
  X_shortcut = X

  #Main Path (3 layers)

  #Layer 1: 1×1 Conv (compression + optional downsampling)
  #Reduces channels to F1 and downsamples (if s=2).
  #No padding; output may shrink.
  X = Conv2D(filters = F1,kernel_size=(1,1),strides=(s,s),padding='valid')(X)
  #BatchNorm helps normalize activations.
  X = BatchNormalization(axis=3)(X,training=training)
  #ReLU for non-linearity.
  X = Activation('relu')(X)

  #Layer 2: f×f Conv (spatial filter)
  #Keeps the spatial size (padding='same').
  #Applies a deeper feature extraction with F2 filters of size f×f.
  X = Conv2D(filters=F2,kernel_size=(f,f),strides=(1,1),padding='same')(X)
  X = BatchNormalization(axis=3)(X,training=training)
  X = Activation('relu')(X)

  #Layer 3: 1x1 Conv (restore depth)
  X = Conv2D(filters=F3,kernel_size=(1,1),strides=(1,1),padding='valid')(X)
  X = BatchNormalization(axis=3)(X,training=training)

  #Shortcut Path (1 layer)
  #Applies a 1×1 convolution to the shortcut connection.
  #This is only done in convolutional blocks to match the dimensions of the main path output.
  X_shortcut = Conv2D(filters = F3,kernel_size=(1,1),strides=(s,s),padding='valid')(X_shortcut)
  X_shortcut = BatchNormalization(axis=3)(X_shortcut,training=training)

  #Add Shortcut
  #Combines the output of the main path and the shortcut path.
  X = Add()([X,X_shortcut])

  #Final Activation
  #Applies ReLU to the combined output.
  X = Activation('relu')(X)

  return X

# %% [markdown]
# **Step 4: Build a Tiny ResNet Model (For CIFAR-10 like images)**

# %%
from tensorflow.keras.initializers import glorot_uniform

def ResNet50(input_shape=(64,64,3),classes=6):
  """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
  """
  # Define the input as a tensor with shape input_shape
  X_input = Input(input_shape)

  # Zero-Padding
  X = ZeroPadding2D(padding=(3,3))(X_input)

  # Stage 1
  X = Conv2D(filters=64,kernel_size=(7,7),strides=(2,2),kernel_initializer=glorot_uniform(seed=0))(X)
  X = BatchNormalization(axis=3)(X)
  X = Activation('relu')(X)
  X = MaxPooling2D(pool_size=(3,3),strides=(2,2))(X)

  # Stage 2
  X = convolutional_block(X,f=3,filters=[64,64,256],s=1)
  X = identity_block(X,3,[64,64,256])
  X = identity_block(X,3,[64,64,256])

  # Stage 3
  X = convolutional_block(X,f=3,filters=[256,256,1024],s=2)
  X = identity_block(X, 3, [256, 256, 1024])
  X = identity_block(X, 3, [256, 256, 1024])
  X = identity_block(X, 3, [256, 256, 1024])
  X = identity_block(X, 3, [256, 256, 1024])
  X = identity_block(X, 3, [256, 256, 1024])

  # Stage 4
  X = convolutional_block(X,f=3,filters=[512,512,2048],s=2)
  X = identity_block(X, 3, [512, 512, 2048])
  X = identity_block(X, 3, [512, 512, 2048])

  #AVGPOOL
  X = AveragePooling2D(pool_size=(2,2))(X)

  # Output layer
  X = Flatten()(X)
  X = Dense(classes,activation='softmax',kernel_initializer=glorot_uniform(seed=0))(X)

  #Create model
  model = Model(inputs=X_input,outputs=X)

  return model

# %%
model = ResNet50(input_shape=(64,64,3),classes=6)
print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_1    │ (None, 70, 70, 3) │          0 │ input_layer_1[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │      9,472 │ zero_padding2d_1… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 15, 15,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 15, 15,    │      4,160 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 15, 15,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 15, 15,    │     16,640 │ activation_5[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 15, 15,    │     16,640 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 15, 15,    │          0 │ add[0][0]         │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 15, 15,    │     16,448 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 15, 15,    │     36,928 │ activation_7[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 15, 15,    │     16,640 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 15, 15,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 15, 15,    │     16,448 │ activation_9[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 15, 15,    │     36,928 │ activation_10[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 15, 15,    │     16,640 │ activation_11[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 15, 15,    │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 15, 15,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 15, 15,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 8, 8, 256) │     65,792 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_14[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_12[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 8, 8,      │          0 │ add_3[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 8, 8, 256) │    262,400 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_17[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 8, 8,      │          0 │ add_4[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 8, 8, 256) │    262,400 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_20[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 8, 8,      │          0 │ add_5[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 8, 8, 256) │    262,400 │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_23[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 8, 8,      │          0 │ add_6[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 8, 8, 256) │    262,400 │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_26[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 8, 8,      │          0 │ add_7[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 8, 8, 256) │    262,400 │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 8, 8,      │    263,168 │ activation_29[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 8, 8,      │          0 │ add_8[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 4, 4, 512) │    524,800 │ activation_30[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 4, 4, 512) │  2,359,808 │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 4, 4,      │  1,050,624 │ activation_32[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 4, 4,      │  2,099,200 │ activation_30[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      8,192 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      8,192 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 4, 4,      │          0 │ add_9[0][0]       │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 4, 4, 512) │  1,049,088 │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 4, 4, 512) │  2,359,808 │ activation_34[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 4, 4,      │  1,050,624 │ activation_35[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      8,192 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ activation_33[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 4, 4,      │          0 │ add_10[0][0]      │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 4, 4, 512) │  1,049,088 │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 4, 4, 512) │  2,359,808 │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 512) │      2,048 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 4, 4, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 4, 4,      │  1,050,624 │ activation_38[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      8,192 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 4, 4,      │          0 │ add_11[0][0]      │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 2, 2,      │          0 │ activation_39[0]… │
# │ (AveragePooling2D)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 8192)      │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 6)         │     49,158 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,078,854 (84.22 MB)
#  Trainable params: 22,032,902 (84.05 MB)
#  Non-trainable params: 45,952 (179.50 KB)
# None

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig / 255.
X_test = X_test_orig / 255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
model.fit(X_train, Y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 160s 5s/step - accuracy: 0.4773 - loss: 1.6189
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 202s 5s/step - accuracy: 0.7204 - loss: 0.7302
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 200s 5s/step - accuracy: 0.8608 - loss: 0.4166
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 160s 5s/step - accuracy: 0.7578 - loss: 2.6891
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 199s 5s/step - accuracy: 0.7672 - loss: 1.1526
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 157s 5s/step - accuracy: 0.8454 - loss: 0.9823
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 204s 5s/step - accuracy: 0.8983 - loss: 0.2691
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 201s 5s/step - accuracy: 0.9388 - loss: 0.1804
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 159s 5s/step - accuracy: 0.9730 - loss: 0.0803
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 161s 5s/step - accuracy: 0.9564 - loss: 0.1426

# %%
# Out:
# Saved artifact at 'hand_signs.h5'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name='keras_tensor_14')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   138412649302160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649303504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649304080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649302544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649303888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649301968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649305616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649306192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649306384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649305232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649302928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649306000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649307920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649308496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649308688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649307536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649303696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649308304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649309072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649313488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649304464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649310992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649311184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649310416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649307152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649310800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649313680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649312912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649310224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649313296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649315216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649315792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649314064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649312336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649311568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412649314832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645712144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645713872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645713488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645716176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645715792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645717712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645718288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645718480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645717328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645718096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645720016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645720784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645719632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645714256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645720400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645722320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645722896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645723088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645721936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645722704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645724624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645725200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645725392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645724240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645718864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645725008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645726928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645727504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645728080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645726160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645727312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645723472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645664528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645666832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645666448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645668368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645669136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645668752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645670672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645671248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645671440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645670288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645664912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645671056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645672976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645673552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645673744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645672592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645673360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645675280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645675856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645676048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645674896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645669520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645675664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645677584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645678160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645678736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645674128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645671824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645677968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645676816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645811024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645813904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645814096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645812944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645810640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645813712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645815632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645811792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645815824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645814480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645816400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645817936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645818704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645817552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645816016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645818320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645820240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645820816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645821008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645819856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645814864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645820624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645822160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645816784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645822928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645824848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645825424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645825616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645826384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645819088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645825232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412645821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644827216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644827792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644828560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644828176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644830096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644830672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644830864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644829712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644828368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644830480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644832400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644832976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644833168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644832016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644827600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644832784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644834704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644835280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644835472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644834320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644828944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644835088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644837008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644837584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644837776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644836624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644831248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644837392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644841616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644842192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644839312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644839888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644833552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644839696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644843152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644835856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644842000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644320464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644319504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644320272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644319312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644322000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644322576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644322768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644321616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644319696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644322384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644324304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644324880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644325072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644323920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644320080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644324688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644326608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644327184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644327376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644326224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644320848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644326992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644328912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644329488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644329680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644328528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644323152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644329296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644331216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644331792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644331984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644330832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644325456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644331600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644333520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138412644334096: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
model.save('hand_signs_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
